# %%
A = [1,2,3,4,5]

# %%
ab = A[len(A)-1]

# %%
B = [x**2 for x in A]
print(B)
# Out:
# [1, 4, 9, 16, 25]

# %% [raw]
# print(B)

# %%
def analyse(A):
    max_A = A[0]
    total_A = 0
    count = 0
    for a in A:
       if a > max_A:
         max_A = a
       total_A = total_A + a
       count = count + 1
       averlage = total_A / count
    return averlage , max_A , total_A

# %%
avg, max_1, total = analyse(B)

# %%
print(avg, max_1, total)
# Out:
# 11.0 25 55

# %%
def analyse(A):
    max_A = None
    total_A = 0
    count = 0
    for a, b in A.items():
       if b > max_A:
         max_A = b
       total_A = total_A + b
       count = count + 1
       averlage = total_A / count
    return round(averlage,2) , max_A , total_A

# %%
C = {"语文":89,"数学":92,"英语":59,"体育":70}
ab, b = C{1}
print(a)
# Out:
#   Cell In[183], line 2
#     ab, b = C{1}
#              ^
# SyntaxError: invalid syntax

# %%
avg, max_1, total = analyse(B)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 avg, max_1, total = analyse(B)
#
# Cell In[96], line 5, in analyse(A)
#       3 total_A = 0
#       4 count = 0
# ----> 5 for a, b in A.items():
#       6    if b > max_A:
#       7      max_A = b
#
# AttributeError: 'list' object has no attribute 'items'

# %%
print(avg, max_1, total)
# Out:
# 11.0 25 55
