# %%
myvar = 3 
myvar += 2 
print(myvar)
# Out:
# 5

# %%
myvar -= 1
print(myvar)
mystring = "Hello"
mystring += "world."
print(mystring)
# Out:
# 4
# Helloworld.

# %%
sample = [1,["another","list"],("a","tuple")]
mylist = ["List item 1",2,3.14]
mylist[0] = "list item 1 again"
mylist[-1] = 3.21
print(len(mylist))
# Out:
# 3

# %%
mydict = {"key": 1, "value": 2, "pi": 3.14}
mydict["pi"] = 3.15
mytuple = (1, 2, 3)
mylist = ["List item 1", 2, 3.14]
print(mylist[:])
print(mylist[0:2])
print(mylist[-3: -1])
print(mylist[1:])
print(mylist[::2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 mydict["pi"] = 3.15
#       3 mytuple = (1, 2, 3)
# ----> 4 a = mytuple**2
#       5 print(a)
#       6 mylist = ["List item 1", 2, 3.14]
#
# TypeError: unsupported operand type(s) for ** or pow(): 'tuple' and 'int'

# %%
rangelist = range(10)
if rangelist[1] == 2:
 print("The second item is 2")
elif rangelist[1] == 3:
 print("The second item is 3")
else:
 print("don't know")
# Out:
# don't know

# %%
i = 1
sum = 0
while(i <= 5):
    sum = sum + i
    i = i + 1
print(sum)
# Out:
# 15

# %%
fruits = ['banana', 'apple', 'mango']
for index in range(len(fruits)):
    print('Current fruit ', fruits[index])
print("Good bye!")
# Out:
# Current fruit  banana
# Current fruit  apple
# Current fruit  mango
# Good bye!

# %%
def func_example(a_list, an_int = 2, a_string = "A default string"):
 a_list.append("A new item")
 an_int = 4
 return a_list, an_int, a_string
my_list = [1, 2, 3]
my_int = 10
print(func_example(my_list,my_int))
# Out:
# ([1, 2, 3, 'A new item'], 4, 'A default string')

# %%
def A(x,y):
  x = x+1
  y=y+1
  return x

# %%
funcvar = lambda x,y : A(x,y)
print(funcvar(1,2))
# Out:
# 2

# %%
import pickle
mylist = ["This", "is", 4, 13327]
myfile = open(r"D:\pasion\项目\实践作业3\file.csv", "wb")
pickle.dump(mylist, myfile)
myfile.close()
myfile = open(r"file.csv", "rb")
loadedlist = pickle.load(myfile)
myfile.close()
print(loadedlist)
myfile = open(r"text.txt", "w")
myfile.write("This is a sample string")
myfile.close()
myfile = open(r"text.txt")
print(myfile.read())
myfile.close()
# Out:
# ['This', 'is', 4, 13327]
# This is a sample string
